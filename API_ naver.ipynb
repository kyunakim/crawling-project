# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 블로그

# %% [markdown]
# https://developers.naver.com/main/

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "LIJD8mAPbkTMJZsQSK0k"
client_secret = "lfFpbSRs5V"

query = urllib.parse.quote(input('검색 질의'))
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의빅데이터
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
bs = BeautifulSoup(xml, 'lxml')
bs.get_text()
# Out:
# "Naver Open API - blog ::'빅데이터'https://search.naver.comNaver Search ResultThu, 28 Jul 2022 10:39:29 +09001144657110<b>빅데이터</b>전문가 준비를 위한 체계적인 방법https://blog.naver.com/nam8853nam?Redirect=Log&logNo=222802704648그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터</b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... 율맘 스토리https://blog.naver.com/nam8853nam20220707<b>빅데이터</b>분석기사 실기 준비를 위한 학습루틴https://blog.naver.com/parkrapp?Redirect=Log&logNo=222753783578안녕하세요, 오늘은 제가 도전한 <b>빅데이터</b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터</b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... 황금빛 쭈롱월드https://blog.naver.com/parkrapp20220531<b>빅데이터</b>전문가 공부했던 과정https://blog.naver.com/kmin4015?Redirect=Log&logNo=222802560555<b>빅데이터</b>전문가 커리큘럼에서 다루고 있는 내용들은 1) 데이터 분석과 해석, 2) R 프로그램, 3) 요인 및 행렬, 4) 배열 및 리스트, 5) 패키지 등으로 구분해 볼 수 있는데요. 필요한 내용은 알차게 모두 구성되어 있는... 나날https://blog.naver.com/kmin401520220707<b>빅데이터</b>전문가 꼼꼼한 학습 노하우https://blog.naver.com/dbsrptkdgod?Redirect=Log&logNo=222
# ...

# %% [markdown]
# ## 과제(0728_1)
# Q. 네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요. (API가이드 참조)

# %%
url
# Out:
# 'https://openapi.naver.com/v1/search/webkr.xml?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&display=100'

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "LIJD8mAPbkTMJZsQSK0k"
client_secret = "lfFpbSRs5V"

query = urllib.parse.quote(input('검색 질의'))

url = "https://openapi.naver.com/v1/search/webkr.xml?query=" + query +'&display='+ str(100)
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의빅데이터
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
bs = BeautifulSoup(response_body, 'lxml')
bs
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><rss version="2.0"><channel><title>Naver Open API - webkr ::'빅데이터'</title><link/>https://search.naver.com<description>Naver Search Result</description><lastbuilddate>Thu, 28 Jul 2022 17:20:14 +0900</lastbuilddate><total>38500863</total><start>1</start><display>75</display><item><title>&lt;b&gt;빅 데이터&lt;/b&gt; 프로세싱 - 나무위키</title><link/>https://namu.wiki/w/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1<description>Big data processing 디지털 시대에서 폭증하는 '방대한 양의 &lt;b&gt;데이터&lt;/b&gt;(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술.</description></item><item><title>&lt;b&gt;빅데이터&lt;/b&gt;란? | 고급 &lt;b&gt;빅데이터&lt;/b&gt; 분석 | SAP Insights</title><link/>https://www.sap.com/korea/insights/what-is-big-data.html<description>비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 &lt;b&gt;빅데이터&lt;/b&gt; 솔루션을 만나보세요.</description></item><item><title>&lt;b&gt;빅 데이터&lt;/b&gt;란 무엇입니까? | Oracle 대한민국</title><link/>https://www.oracle.com/kr/
# ...

# %%
import pandas as pd
data_df = pd.DataFrame(columns=['title', 'link', 'description'])

# %%
titles = bs.find_all('title')
links = bs.find_all('link')
texts = bs.find_all('description')
display = bs.find('display')
# texts = bs.find_all('description')

i=0
for title in titles:
    data_df.loc[i,'title'] =title.get_text()
#     data_df.loc[i,'title'] =title.string
    i+= 1
    
i=0
for link in links:
    data_df.loc[i,'link'] =link.get_text()
    i+= 1

i=0
for text in texts:
    data_df.loc[i,'description'] =text.get_text()
    i+= 1

# %%
data_df
# Out:
#                                                 title link  \
# 0                     Naver Open API - webkr ::'빅데이터'
# 1                            <b>빅 데이터</b> 프로세싱 - 나무위키
# 2    <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 3                  <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 4    <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# ..                                                ...  ...
# 71  <b>빅데이터</b>에 관한 인기 아이디어 270개 | <b>빅데이터</b>, 파이...
# 72                       <b>빅데이터</b> 전문기업 빅스터 BIGSTER
# 73             #<b>빅데이터</b> 해시태그 • Instagram 사진 및 동영상
# 74                    아임클라우드 – 인공지능, <b>빅데이터</b> 전문기업
# 75                             '<b>빅데이터</b>' 태그의 글 목록
#
#                                           description
# 0                                 Naver Search Result
# 1   Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데...
# 2   비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도...
# 3   <b>빅데이터</b>는 특히 새로운 <b>데이터</b> 소스에서 나온 더 크고 더 ...
# ...

# %%
import os
import sys
import urllib.request
client_id = "NlyY4vYvuvzxx0l7vhB8"
client_secret = "0mDeMw5Q0v"
encText = urllib.parse.quote("빅데이터")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Jul 2022 11:14:03 +0900",
# 	"total":38494849,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅 데이터<\/b> 프로세싱 - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1",
# 			"description":"Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터<\/b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>란? | 고급 <b>빅데이터<\/b> 분석 | SAP Insights",
# 			"link":"https:\/\/www.sap.com\/korea\/insights\/what-is-big-data.html",
# 			"description":"비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 <b>빅데이터<\/b> 솔루션을 만나보세요."
# 		},
# 		{
# 			"title":"<b>빅 데이터<\/b>란 무엇입니까? | Oracle 대한민국",
# 			"link":"https:\/\/www.oracle.com\/kr\/big-data\/what-is-big-data\/",
# 			"description":"<b>빅데이터<\/b>는 특히 새로운 <b>데이터<\/b> 소스에서 나온 더 크고 더 복잡한 <b>데이터<\/b> 세트입니다. <b>빅데이터<\/b>의 이점, 과제 및 모범 사례 외에도 정의 및 역사에 대해 알아보세요."
# 		},
# 		{
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8')) #한꺼번에 가져옥
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [88], in <cell line: 4>()
#       2 warnings.filterwarnings('ignore')
#       3 import pandas as pd
# ----> 4 df = pd.read_json(response_body.decode('utf-8')) #한꺼번에 가져옥
#       5 df.info()
#       6 df['items']
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\Anaconda3\envs\cakd7\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
df['items']
# Out:
# 0    {'title': '<b>빅 데이터</b> 프로세싱 - 나무위키', 'link': ...
# 1    {'title': '<b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 |...
# 2    {'title': '<b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국'...
# 3    {'title': '<b>빅데이터</b>(big data) 이해 - 정의, 분석, ...
# 4    {'title': '네이버 <b>데이터</b>랩', 'link': 'https://...
# 5    {'title': '<b>빅데이터</b> - BC카드', 'link': 'https...
# 6    {'title': '트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자<b>...
# 7    {'title': '국가기술 <b>빅데이터</b> 분석기사 - <b>데이터</b>자...
# 8    {'title': '<b>빅데이터</b>의 이해 - 글이 작품이 되는 공간, 브런치...
# 9    {'title': '미디어백과: <b>빅데이터</b> - 네이버 지식백과', 'li...
# Name: items, dtype: object

# %% [markdown]
# ## 과제(0728_2)
# Q. 뉴스, 영화, 쇼핑, 지식인, 카페글에서 적합한 주제에 대한 데이터를 가져와서 데이터 프레임으로 출력하세요.

# %% [markdown]
# ## 과제(0728_3)
#
#  > 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# <BR><BR>
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# ```
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5
# ```

# %% [markdown]
# # 공공데이터포털
# - 소상공인 상가 업소정보 <br>
# https://www.data.go.kr/data/15012005/openapi.do

# %% [markdown]
# ① 지정 상권조회(storeZoneOne) <br>
# baroApi 오퍼레이션 사용 : <br>
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&key=9144&ServiceKey=서비스인증키

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

#service key
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'storezone'
stype = 'json'

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + urlencode({quote_plus('key'):'9174'}) #위의 url형태에서 type을 추가함
# params ={'serviceKey' : '서비스키', 'key' : '9174', 'type' : 'xml' } #기본양식
query = url + params
print(query)

request = Request(query)
request.get_method=lambda:'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D&type=json&resId=storezone&key=9174
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %% [markdown]
# ## 함수화

# %%
#함수화
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

def baro_api(skey,res_id,encode):
    global df
    stype = 'json'
    
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&' + encode
    query = url + params
    
    request = Request(query)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ## 상권조회

# %% [markdown]
# 1) 지정 상권조회 오퍼레이션 명세	14 <br>
# 2) 반경내 상권조회 오퍼레이션 명세	17 <br>
# 3) 사각형내 상권조회 오퍼레이션 명세	20 <br>
# 4) 행정구역 단위 상권조회 오퍼레이션 명세	24 <br>
# <br>
# 8) 행정동 단위 상가업소 조회 오퍼레이션 명세	42

# %% [markdown]
# ### 지정 상권조회(9193)

# %%
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'storezone'

encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# ### 반경내 상권조회

# %%
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'storezone'

encode = urlencode({quote_plus('catId'):'radius',
                  quote_plus('radius'):'500',
                  quote_plus('cx'):'127.004528',
                  quote_plus('cy'):'37.567538'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# ### 과제(0728_4)
# 사각형내 상권조회

# %%
http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=rectangle&minx=126.978020&miny=37.557825&maxx=126.987732&maxy=37.562022&ServiceKey=서비스인증키

# %%
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'storezone'

encode = urlencode({quote_plus('catId'):'rectangle',
                  quote_plus('minx'):'126.978020',
                  quote_plus('miny'):'37.557825',
                  quote_plus('maxx'):'126.987732',
                  quote_plus('maxy'):'37.562022'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9191      남대문시장       11    서울특별시    11140       중구    111020        27
# 1    9196        명동역       11    서울특별시    11140       중구     96649        28
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.976451547074 37.5576325944...  2021-06-30
# 1  MULTIPOLYGON (((126.983476244148 37.5605598377...  2021-06-30

# %% [markdown]
# ### 과제(0728_5)
# 행정구역 단위 상권조회

# %%
http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=dong&divId=adongCd&key=1168069000&ServiceKey=서비스인증키

# %%
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'store'

encode = urlencode({quote_plus('key'):'1168069000',
                    quote_plus('catId'):'dong',
                    quote_plus('divId'):'adongCd'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId        bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10372656     한스공인중개사사무소                 L        부동산        L01
# 1   11752840           오페라빈                 Q         음식        Q01
# 2   11794107          러빙헛카페                 Q         음식        Q12
# 3   11796806       파스쿠찌국악고점   국악고점          Q         음식        Q12
# 4   11799567             그집                 Q         음식        Q01
# 5   11799618       김승우의뼈감자탕                 Q         음식        Q01
# 6   11799629    배스킨라빈스31포이점    포이점          Q         음식        Q07
# 7   11799634          바로본안경                 D         소매        D18
# 8   11799688     우리들의편의점개포점    개포점          D         소매        D03
# 9   11872043         닥터큐헤어샵                 F      생활서비스        F01
# 10  11928583  호식이두마리치킨개포1호점  개포1호점          Q         음식        Q05
# 11  11958998           GS25  개포사랑점          D         소매        D03
# 12  11968513         모아필라테스    개포점          N   관광/여가/오락        N05
# ...

# %% [markdown]
# ### 과제(0728_6) - 내용 파악
# 행정동 단위 상가업소 조회

# %%
http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=dong&divId=ctprvnCd&key=11&ServiceKey=서비스인증키

# %%
skey = 'i535ypRLhAuPwClfOxcBuBcOSoJnn4VImgZ45gT7gvWAMUELH7%2FSABnCDBC68oEmVvqd%2F5%2BY8T2R1c6zGS2llA%3D%3D'
res_id = 'store'

encode = urlencode({quote_plus('key'):'11',
                    quote_plus('catId'):'dong',
                    quote_plus('divId'):'ctprvnCd'})

baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
