# %% [markdown]
# # 문제제기

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. '도박' 키워드
# - 2019~2022 현재까지 '도박' 키워드 중 '청소년'이 차지하는 비율 비교

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df, keyword

def News(keyword, ex_keyword, num, start_date, end_date):
    global news_df, url,page_num
    
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    ex_keyword = urllib.parse.quote(ex_keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+ '+-' + ex_keyword + '&photo=3'+'&pd=3'+ '&ds='+start_date+'&de='+end_date+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

#검색키워드, 제외키워드, num, start_date, end_date 
# News('도박','양현석', 1000,'2019.01.01','2019.12.31')
# News('도박','공무원', 1000,'2020.01.01','2020.12.31')
# News('도박','이재명', 1000,'2021.01.01','2021.12.31')
News('도박','공무원', 600,'2022.01.01','2022.07.31')
# Out:
#                                                 title  \
# 0                        “100배 수익”… 개미들, 도박처럼 코인선물 베팅
# 1                 강원랜드 도박중독 회복자, 직접 재배한 감자 지역 나눔 '훈훈'
# 2                  도박장 된 게임 불법 사설서버... 리니지·바람의나라 등 다양
# 3                    100만원 넣고 30배 먹는다…주식판 깨지자 도박판 열렸다
# 4       웹툰 '도박중독자의 가족', 왜 고통은 똑똑한 여성의 몫인가[위근우의 리플레...
# ..                                                ...
# 595                       경찰 “성남FC사건 檢 요청 부분 다시 살필 것”
# 596                   “사생활, 개인일탈” 잇단 총기사고…경찰 멘털 관리 절실
# 597               “정민용, 이재명 시장 비서실에 대장동 보고서 여러 차례 전달”
# 598  [줌인 예수를 플렉스하다] <1> MZ세대 4인 ‘줌인톡톡’ 삶과 신앙을 이야기하...
# 599                               [세풍] 화성산업, 27년 전 그날
#
#                                                    url
# 0    https://www.donga.com/news/article/all/2022072...
# 1    http://www.kado.net/news/articleView.html?idxn...
# 2        http://www.fnnews.com/news/202207041804526633
# 3    http://www.edaily.co.kr/news/newspath.asp?news...
# 4    https://www.khan.co.kr/culture/culture-general...
# ..                                                 ...
# 595  http://www.segye.com/content/html/2022/03/14/2...
# 596  http://www.edaily.co.kr/news/newspath.asp?news...
# 597  http://www.segye.com/content/html/2022/03/14/2...
# 598  http://news.kmib.co.kr/article/view.asp?arcid=...
# 599  https://news.imaeil.com/page/view/202203141746...
#
# [600 rows x 2 columns]

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_word = ['도박','불법','범죄','만원','단독']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_word:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기

#2019
# data19 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data19)
# df=pd.DataFrame(series, columns=['cnt'])
# student_2019 =df.loc['청소년'].cnt

#2020
# data20 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data20)
# df=pd.DataFrame(series, columns=['cnt'])
# student_2020 =df.loc['청소년'].cnt

# 2021
# data21 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data21)
# df=pd.DataFrame(series, columns=['cnt'])
# student_2021 =df.loc['청소년'].cnt

# 2022
data22 =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data22)
df=pd.DataFrame(series, columns=['cnt'])
student_2022 =df.loc['청소년'].cnt

df
# Out:
#      cnt
# 횡령    44
# 직원    36
# 투자    26
# 코인    22
# 주식    18
# ..   ...
# 예수     1
# 플렉스    1
# 신앙     1
# 화성     1
# 그날     1
#
# [1954 rows x 1 columns]

# %%
import pandas as pd
# df.to_excel('도박noun_2019.xlsx')
# df.to_excel('도박noun_2020.xlsx')
# df.to_excel('도박noun_2021.xlsx')
df.to_excel('도박noun_2022.xlsx')

# %% [markdown]
# ## 2019

# %%
data19.pop('트럼프')
data19.pop('만원')
data19.pop('단독')
# Out:
# 20

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data19)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ## 2020

# %%
data20.pop('트럼프')
data20.pop('만원')
data20.pop('단독')
# Out:
# 2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data20)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ## 2021

# %%
data21.pop('칼럼')
# Out:
# 40

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data21)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ## 2022

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data22)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ## 2019-2022 '도박' 중 '청소년' cnt

# %%
student_cnt =pd.DataFrame(columns=['cnt'])
student_cnt
# Out:
# Empty DataFrame
# Columns: [cnt]
# Index: []

# %%
student_cnt.loc[0,'cnt'] =student_2019.cnt
student_cnt.loc[1,'cnt'] =student_2020.cnt
student_cnt.loc[2,'cnt'] =student_2021.cnt
student_cnt.loc[3,'cnt'] =student_2022.cnt

# %%
student_cnt.index = student_cnt.index+2019
student_cnt
# Out:
#      cnt
# 2019   9
# 2020   5
# 2021  15
# 2022  10

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',family="Malgun Gothic") #한글폰트

sns.barplot(x=student_cnt.index, y=student_cnt.cnt, data=student_cnt)
plt.title("2019-2022상반기, '도박' 중 '청소년' 키워드", size=18)
# Out:
# Text(0.5, 1.0, "2019-2022상반기, '도박' 중 '청소년' 키워드")

# %% [markdown]
# ## 2. '청소년 불법' 키워드
# - 2019~2022 현재까지 '청소년 ' 키워드 중 '도박'이 차지하는 비율 비교

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df, keyword

def News(keyword, ex_keyword, num, start_date, end_date):
    global news_df, url,page_num
    
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    ex_keyword = urllib.parse.quote(ex_keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+ '+-' + ex_keyword + '&photo=3'+'&pd=3'+ '&ds='+start_date+'&de='+end_date+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

#검색키워드, 제외키워드, num, start_date, end_date 
# News('도박','양현석', 1000,'2019.01.01','2019.12.31')
# News('도박',' ', 1000,'2020.01.01','2020.12.31')
# News('도박','이재명', 1000,'2021.01.01','2021.12.31')
News('도박','공무원', 600,'2022.01.01','2022.07.29')
# Out:
#                                                 title  \
# 0                        “100배 수익”… 개미들, 도박처럼 코인선물 베팅
# 1                 강원랜드 도박중독 회복자, 직접 재배한 감자 지역 나눔 '훈훈'
# 2                  도박장 된 게임 불법 사설서버... 리니지·바람의나라 등 다양
# 3                    100만원 넣고 30배 먹는다…주식판 깨지자 도박판 열렸다
# 4       "도박사이트 운영자 무관용 처벌… 중독 예방 교육 병행" [범람하는 불법도박...
# ..                                                ...
# 595                       경찰 “성남FC사건 檢 요청 부분 다시 살필 것”
# 596                   “사생활, 개인일탈” 잇단 총기사고…경찰 멘털 관리 절실
# 597               “정민용, 이재명 시장 비서실에 대장동 보고서 여러 차례 전달”
# 598  [줌인 예수를 플렉스하다] <1> MZ세대 4인 ‘줌인톡톡’ 삶과 신앙을 이야기하...
# 599                               [세풍] 화성산업, 27년 전 그날
#
#                                                    url
# 0    https://www.donga.com/news/article/all/2022072...
# 1    http://www.kado.net/news/articleView.html?idxn...
# 2        http://www.fnnews.com/news/202207041804526633
# 3    http://www.edaily.co.kr/news/newspath.asp?news...
# 4        http://www.fnnews.com/news/202206301803336103
# ..                                                 ...
# 595  http://www.segye.com/content/html/2022/03/14/2...
# 596  http://www.edaily.co.kr/news/newspath.asp?news...
# 597  http://www.segye.com/content/html/2022/03/14/2...
# 598  http://news.kmib.co.kr/article/view.asp?arcid=...
# 599  https://news.imaeil.com/page/view/202203141746...
#
# [600 rows x 2 columns]

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
# stop_word = ['도박','불법','범죄']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        # if word not in stop_word:
        noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기

#2019
# data19 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data19)

#2020
# data20 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data20)

# 2021
# data21 =dict(count.most_common()) #빈도수 정리 내림차
# series = pd.Series(data21)

#2022
data22 =dict(count.most_common()) #빈도수 정리 내림차
series = pd.Series(data22)

df=pd.DataFrame(series, columns=['cnt'])

#청소년 키워드
# student_2019 =df.loc['청소년']
# student_2019

# student_2020 =df.loc['청소년']
# student_2020

# student_2021 =df.loc['청소년']
# student_2021

student_2022 =df.loc['청소년']
student_2022
# Out:
# cnt    10
# Name: 청소년, dtype: int64

# %% [markdown]
# # 원인

# %% [markdown]
# ## 1. '청소년 도박 원인' 키워드
# - 청소년 도박에 영향을 미치는 요인들

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

News()

# 청소년 도박 원인
# 1000
# Out:
# 검색 키워드를 입력해주세요 청소년 도박 원인
# 필요한 뉴스기사의 숫자를 입력해주세요 1000
#                                              title  \
# 0                        청소년불법도박, 어떠한 경우에도 선처 불가능해
# 1               '아이 어른 할 것 없이 베팅'…한탕주의 도박 늪에 빠진 충북
# 2                            소년범죄, 원인부터 살피고 대책 논의를
# 3    "도박사이트 운영자 무관용 처벌… 중독 예방 교육 병행" [범람하는 불법도박...
# 4                     [공공돋보기] 학교폭력 도화선 '청소년 도박 중독'
# ..                                             ...
# 995               [충청브리핑] 바른정당 의원 14명 ‘洪 지지’ 탈당 결의
# 996             [취재] 아이와 부모의 게임 소통? "함께 공감하고 대화해요"
# 997                    시중銀, 가상화폐거래소에 가상계좌 380만개 남발
# 998                             아이와 스마트폰 신경전 끝내는 법
# 999     [게임이슈 '콕!'] 오락실의 추억, '아케이드 게임'의 흥망성쇠에 대하여…
#
#                                                    url
# 0    http://www.globalepic.co.kr/view.php?ud=202207...
# 1               https://www.news1.kr/articles/?4742532
# 2    https://www.hani.co.kr/arti/opinion/because/10...
# 3        http://www.fnnews.com/news/202206301803336103
# 4    http://www.00news.co.kr/news/articleView.html?...
# ..                                                 ...
# 995  http://www.newdaily.co.kr/news/article.html?no...
# 996   http://www.inven.co.kr/webzine/news/?news=192577
# 997    http://decenter.sedaily.com/NewsView/1RUH6DWV01
# 998  http://www.sisain.co.kr/?mod=news&act=articleV...
# 999   http://www.inven.co.kr/webzine/news/?news=153103
#
# [1000 rows x 2 columns]

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_words = ['도박', '예방', '불법', '문제', '청소년','원인','중독','교육','도박중독','범죄','센터','한국','질병','게임중독','장애','코드','규제','사회','산업','아이','업계','치료','몰입','도입','뉴스','논란','이유','학생','대책','문화','이용','관리','증상','이슈','성인','칼럼','기획','교육청','위험','심각','상담','복지','급증',]
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_words:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기
data =dict(count.most_common(10)) #빈도수 정리 내림차(15위까지만)
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

# %% [markdown]
# - wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)

# %% [markdown]
# ### 정리
# - 게임, 스포츠, 경마 : 청소년 도박은 게임형태로 제공됨
# - 코로나, 스마트폰, 인터넷 : 코로나 19 이후, 스마트폰과 인터넷 사용이 과다해지고 도박 광고에 노출됨
# - 제주 : 제주도의 청소년 도박은 가장 심각한 수준

# %% [markdown]
# # 청소년 치료 실태

# %% [markdown]
# ## 1. 지식인 '청소년 도박' > 도움의 필요성
# - description의 verb추출

# %%
import pandas as pd
data_df = pd.DataFrame(columns=['title', 'description'])

# %%
data_df
# Out:
# Empty DataFrame
# Columns: [title, description]
# Index: []

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "LIJD8mAPbkTMJZsQSK0k"
client_secret = "lfFpbSRs5V"

# query = urllib.parse.quote(input('검색 질의'))
query = urllib.parse.quote('청소년 도박')

# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(1)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(101)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(201)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(301)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(401)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(501)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(601)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(701)
# url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(801)
url = "https://openapi.naver.com/v1/search/kin.xml?query=" + query +'&display='+ str(100) + '&start='+str(901)

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    response_body=response_body.decode('utf-8')
else:
    print("Error Code:" + rescode)

# %%
from bs4 import BeautifulSoup
bs = BeautifulSoup(response_body, 'html.parser')

titles = bs.find_all('title')
texts = bs.find_all('description')
display = bs.find('display')
# texts = bs.find_all('description')

# i=0
for title in titles:
    data_df.loc[i,'title'] =title.get_text()
    data_df.loc[i,'title'] = re.sub('[^가-힣]',' ',data_df.loc[i,'title'])
    i+= 1

# j=0
for text in texts:
    data_df.loc[j,'description'] =text.get_text()
    data_df.loc[j,'description'] = re.sub('[^가-힣]',' ',data_df.loc[j,'description'])
    j+= 1

data_df
# Out:
#                                  title  \
# 0                              청소년 도박
# 1             청소년 도박     문제점 알려주세요 급해요
# 2                         청소년 도박    처벌
# 3                         청소년 도박    중독
# 4                         청소년 도박     빚
# ...                                ...
# 1005                     온라인으로 돈버는 방법
# 1006        아들이 던파에빠져    만원을    도와주세요
# 1007     제가 스크린골프장에서 알바를 했었는데요  제가
# 1008       아는 지인이 중고사기로 곧 재판을 봅니다
# 1009  수시지원때문에 자기소개서를 작성했는데   수정해야될
#
#                                             description
# 0
# 1     내일 국어에서 발표하기를 하는데요    청소년 도박     문제점 좀 알려주세요  ...
# 2         부터    도박    했고요 넣다 뺏다 천만원 정도 한것같은데 경찰에 걸리면...
# 3         원래    도박     같은건 한번도 하지 않았는데 주변 친구들로    진짜...
# 4     이제 고 인데    도박    을 하다 친구들에게 거짓말을 쳐서 돈을 빌리고 하다 ...
# ...                                                 ...
# 1005       불법     도박     말고요  안녕하세요     청소년    근로보호센...
# 1006      아니죠 이긴사람이 가져가죠 그겁니다 아드님은    도박    에 실패한겁니다...
# 1007         도박    으로 게임치러 오는사람이 많아요  하루에    만원 쓰는 사...
# 1008      또한 그 돈을 불법   도박    사이트에서 사용하였습니다  그리하여 이 사...
# 1009        살 때 아버지의    도박     빚으로 인해 가족이 모두 헤체가 되었고...
#
# [1010 rows x 2 columns]

# %%
import re
target =data_df['description'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
text1 = text

# %%
import pandas as pd
stopword = pd.read_csv('stopword_korean.csv', header=None)
stopword=stopword.values.tolist()
stop_word=[]
for i in range(len(stopword)):
    stop_word += stopword[i]
stop_word
# Out:
# ['입니다', '있습니다']

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

verb_list =[]
for word, tag in morph: #word= 단어 / tag=품사
    if (tag=='noun') | (tag=='verb') |(tag=='Adjective'):
        if word not in stop_word:
            verb_list.append(word)

count = Counter(verb_list) #단어별 숫자세주기
data =dict(count.most_common()) #빈도수 정리 내림차(15위까지만)
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])

# %%
data
# Out:
# {'있는': 97,
#  '안녕하세요': 82,
#  '같은': 71,
#  '어떻게': 64,
#  '있고': 38,
#  '아니라': 31,
#  '어떤': 28,
#  '있어': 27,
#  '없습니다': 27,
#  '많은': 26,
#  '같습니다': 21,
#  '그런': 21,
#  '이런': 21,
#  '없는': 20,
#  '있나요': 19,
#  '있으므로': 18,
#  '있는지': 18,
#  '가능한': 18,
#  '같은데': 16,
#  '아니면': 15,
#  '있어요': 15,
#  '있다고': 15,
#  '있는데': 15,
#  '인해': 14,
#  '있을까요': 14,
#  '같아요': 12,
#  '있을': 12,
#  '어떠한': 12,
#  '좋은': 12,
#  '있다': 12,
#  '많다': 12,
#  '아니고': 11,
#  '가능합니다': 11,
#  '있으니': 11,
#  '아니죠': 11,
#  '없어서': 11,
#  '아닌': 10,
#  '안된다고': 10,
#  '있다는': 10,
#  '같아서': 10,
#  '험악한': 10,
#  '안되는': 9,
#  '아닙니다': 9,
#  '나쁜': 9,
#  '힘든': 9,
#  '불우한': 9,
#  '높습니다': 9,
#  '그럼': 9,
#  '같': 9,
#  '같은거는': 9,
#  '없어요': 8,
#  '인한': 8,
#  '부탁드립니다': 8,
#  '있으면': 8,
#  '있기': 8,
#  '엄격한': 8,
#  '자세하게': 8,
#  '없는데': 8,
#  '가능한가요': 8,
#  '의하여': 8,
#  '솔직히': 7,
#  '안됩니다': 7,
#  '없고': 7,
#  '같은거': 7,
#  '있으며': 7,
#  '미': 7,
#  '같네요': 7,
#  '없으면': 7,
#  '있지만': 6,
#  '힘듭니다': 6,
#  '같아': 6,
#  '많습니다': 6,
#  '단순히': 6,
#  '있어서': 6,
#  '상당히': 6,
#  '궁금합니다': 6,
#  '나쁜건': 6,
#  '가깝죠': 6,
#  '가볍게': 6,
#  '그러니': 6,
#  '없음': 6,
#  '의한': 6,
#  '같은건': 5,
#  '없나요': 5,
#  '없지만': 5,
#  '의해': 5,
#  '없어': 5,
#  '이러한': 5,
#  '다양한': 5,
#  '궁금해서': 5,
#  '빠른': 5,
#  '그러고': 5,
#  '있죠': 5,
#  '좋지': 5,
#  '비슷한': 5,
#  '좋습니다': 5,
#  '어렵습니다': 5,
#  '당연히': 5,
#  '불가능하며': 5,
#  '없다고': 5,
#  '건전한': 5,
#  '아닌가요': 5,
#  '필요한': 5,
#  '빠르게': 4,
#  '좋을까요': 4,
#  '미치겠습니다': 4,
#  '심각한': 4,
#  '자세한': 4,
#  '그런거': 4,
#  '진지하게': 4,
#  '좋아하여서': 4,
#  '안되면': 4,
#  '아니': 4,
#  '정확한': 4,
#  '안녕하세여': 4,
#  '아니더라도': 4,
#  '똑같다고': 4,
#  '인해서': 4,
#  '필요합니다': 4,
#  '많아서': 4,
#  '어려워서': 4,
#  '귀찮은지': 4,
#  '같은것도': 4,
#  '먼': 4,
#  '많지': 4,
#  '높은': 4,
#  '없네요': 4,
#  '같은걸': 4,
#  '유해한': 4,
#  '있음': 4,
#  '흔히': 4,
#  '안될거': 4,
#  '있었는데': 4,
#  '있도록': 4,
#  '약한': 4,
#  '있지': 3,
#  '아니라면': 3,
#  '어려운': 3,
#  '있겠지만': 3,
#  '왠만하면': 3,
#  '새로운': 3,
#  '안된다는걸': 3,
#  '당했습니다': 3,
#  '완전히': 3,
#  '원할': 3,
#  '이런게': 3,
#  '안되고': 3,
#  '민감한': 3,
#  '있다면': 3,
#  '궁금한': 3,
#  '있어도': 3,
#  '자세히': 3,
#  '상관없이': 3,
#  '힘들어진': 3,
#  '편찮으셔서': 3,
#  '명백히': 3,
#  '힘들게': 3,
#  '힘들어': 3,
#  '어떨까': 3,
#  '이런거': 3,
#  '특별히': 3,
#  '이상한': 3,
#  '낮겠다': 3,
#  '그러다': 3,
#  '안전한': 3,
#  '좀있는대요': 3,
#  '당하면': 3,
#  '야한': 3,
#  '많은데': 3,
#  '부탁드려요': 3,
#  '그러한': 3,
#  '궁금해서요': 3,
#  '아니하고': 3,
#  '없다는': 3,
#  '같다고': 3,
#  '위험한': 3,
#  '고통스러운': 3,
#  '낮게': 3,
#  '반갑습니다': 3,
#  '더라고요': 3,
#  '젊은': 3,
#  '있을거': 2,
#  '작은': 2,
#  '굉장히': 2,
#  '힘들고': 2,
#  '무섭고': 2,
#  '많기': 2,
#  '진지한': 2,
#  '어떡하면': 2,
#  '없고요': 2,
#  '힘들어요': 2,
#  '힘들': 2,
#  '급합니다': 2,
#  '안되': 2,
#  '건전하게': 2,
#  '충분히': 2,
#  '팔팔한나이인데': 2,
#  '하찮은': 2,
#  '불안합니다': 2,
#  '좋을': 2,
#  '좋겠죠': 2,
#  '그럴': 2,
#  '원하는': 2,
#  '이런데': 2,
#  '같던데': 2,
#  '강한': 2,
#  '미치는': 2,
#  '불안해요': 2,
#  '있군요': 2,
#  '스럽습니다': 2,
#  '전화하면': 2,
#  '야합니다': 2,
#  '같은데요': 2,
#  '있는가': 2,
#  '있던데': 2,
#  '귀엽고': 2,
#  '예쁜': 2,
#  '있었던': 2,
#  '막막하고': 2,
#  '같고': 2,
#  '안되나요': 2,
#  '건전하지': 2,
#  '없기': 2,
#  '없던': 2,
#  '위험합니다': 2,
#  '힘들겠죠': 2,
#  '원활히': 2,
#  '이럴': 2,
#  '가능하며': 2,
#  '아니고요': 2,
#  '원하신다면': 2,
#  '확실히': 2,
#  '필요할것으로': 2,
#  '좋을것': 2,
#  '힘들어서': 2,
#  '아니라고': 2,
#  '아니지만': 2,
#  '인하여': 2,
#  '부끄럽지만': 2,
#  '있거나': 2,
#  '있는대': 2,
#  '뿐입니다': 2,
#  '없구요': 2,
#  '같으면': 2,
#  '안될': 2,
#  '없으며': 2,
#  '필요하다고': 2,
#  '전화하셔서': 2,
#  '있': 2,
#  '외롭게': 2,
#  '안될까': 2,
#  '있었거든요': 2,
#  '그러더라구요': 2,
#  '아무런': 2,
#  '엄연한': 2,
#  '전화해서': 2,
#  '끊임없이': 2,
#  '있겠네요': 2,
#  '없다고하면': 2,
#  '중요합니다': 2,
#  '궁금하네요': 2,
#  '안되시고': 2,
#  '해로운': 2,
#  '있었다면': 2,
#  '좋겠네요': 2,
#  '바람직하게': 2,
#  '어렵듯이': 2,
#  '없을': 2,
#  '부족해서': 2,
#  '있으시면': 2,
#  '아니에요': 2,
#  '정확히': 2,
#  '손쉽게': 2,
#  '있구요': 2,
#  '미안하다고하시고': 2,
#  '부으시고': 2,
#  '답답합니다': 2,
#  '그럴건데': 2,
#  '재밌는데': 2,
#  '있는데요': 2,
#  '높고': 2,
#  '있을까': 2,
#  '없다': 2,
#  '안좋은': 2,
#  '건강한': 2,
#  '어떡할': 2,
#  '좋아합니다': 2,
#  '정확히는': 2,
#  '웬만하면': 2,
#  '올바르지': 2,
#  '안되던데': 2,
#  '당하고': 2,
#  '싫어하셔서': 2,
#  '유해하거나': 2,
#  '좋은지': 2,
#  '마라': 2,
#  '멋진': 2,
#  '완벽한': 2,
#  '음란한': 2,
#  '불가능합니다': 2,
#  '싫고': 2,
#  '평범한': 2,
#  '아닌가': 2,
#  '다르겠지만': 2,
#  '중요한': 2,
#  '별다른': 2,
#  '미친': 2,
#  '불우했구요': 2,
#  '이로인해': 2,
#  '답답해서': 2,
#  '마땅히': 2,
#  '없다가': 2,
#  '있고요': 2,
#  '그렇습니다': 2,
#  '많아요': 2,
#  '어려워요': 2,
#  '방탕한': 2,
#  '급하시다면': 1,
#  '없다면': 1,
#  '상관없습니다': 1,
#  '미쳐': 1,
#  '아니시다면': 1,
#  '궁금하시다면': 1,
#  '두렵습니다': 1,
#  '솔직하게': 1,
#  '야해요': 1,
#  '위험하잖아요': 1,
#  '심심해서': 1,
#  '좋겠습니다': 1,
#  '있어야겠지요': 1,
#  '특수한': 1,
#  '불안한데': 1,
#  '불가능해지나요': 1,
#  '안되게': 1,
#  '당했다': 1,
#  '머니를': 1,
#  '강화한다': 1,
#  '많고': 1,
#  '어떤게': 1,
#  '없으므로': 1,
#  '적절한': 1,
#  '아니구요': 1,
#  '당할지': 1,
#  '급해요': 1,
#  '있던': 1,
#  '원하시면': 1,
#  '그래요': 1,
#  '정확하게': 1,
#  '똑같습니다': 1,
#  '심심할': 1,
#  '중요하니': 1,
#  '있으시군요': 1,
#  '부탁드리겠습니다': 1,
#  '다르죠': 1,
#  '계시다면': 1,
#  '안되겠다': 1,
#  '행복하세요': 1,
#  '좋잖아요': 1,
#  '작지': 1,
#  '힘들지만': 1,
#  '두둑히': 1,
#  '짜릿함': 1,
#  '부러웠습니다': 1,
#  '그렇고': 1,
#  '흔히말하는': 1,
#  '많이하던데': 1,
#  '어렵죠': 1,
#  '달라하였고': 1,
#  '소소하게': 1,
#  '가능하구요': 1,
#  '같은것이니': 1,
#  '나쁜거말고': 1,
#  '재미있게': 1,
#  '고소한다': 1,
#  '간편하게': 1,
#  '특별한게': 1,
#  '뿐이니': 1,
#  '한심하겠지만': 1,
#  '심각하고': 1,
#  '안녕하세용': 1,
#  '희박한': 1,
#  '아닌듯': 1,
#  '많더라구요': 1,
#  '어떡하죠': 1,
#  '야하며': 1,
#  '무서운': 1,
#  '그렇다면': 1,
#  '같은거도': 1,
#  '그랬지만': 1,
#  '죄송해서': 1,
#  '많았어서': 1,
#  '같은거요': 1,
#  '궁금하구': 1,
#  '쎄지는지': 1,
#  '간단히': 1,
#  '아니거든요': 1,
#  '있자나여': 1,
#  '좋지도': 1,
#  '나쁘지도': 1,
#  '편해요': 1,
#  '스럽네요': 1,
#  '강해서': 1,
#  '죄송하다고': 1,
#  '성실한': 1,
#  '만연하고': 1,
#  '넘쳐나면': 1,
#  '어지럽고': 1,
#  '스러울': 1,
#  '아니라서': 1,
#  '있다만': 1,
#  '힘든게': 1,
#  '있지요': 1,
#  '있으시겠네요': 1,
#  '흉해서': 1,
#  '순순히': 1,
#  '엄중한': 1,
#  '많다고하는데': 1,
#  '가능하면': 1,
#  '높다는': 1,
#  '있으나': 1,
#  '엄중히': 1,
#  '심하고': 1,
#  '다른데': 1,
#  '계시군요': 1,
#  '죄송한': 1,
#  '다릅니다': 1,
#  '없을까': 1,
#  '미치도록': 1,
#  '가능하다면': 1,
#  '있으': 1,
#  '없게': 1,
#  '성숙한': 1,
#  '없죠': 1,
#  '심각해여': 1,
#  '아니시고': 1,
#  '없으니': 1,
#  '원해': 1,
#  '난감하시겠어요': 1,
#  '없어도': 1,
#  '사나워': 1,
#  '심심하시다면': 1,
#  '재미있어요': 1,
#  '많으면': 1,
#  '미를': 1,
#  '심각한가요': 1,
#  '어떠한가요': 1,
#  '힘들어하고': 1,
#  '안타깝게도': 1,
#  '스럽': 1,
#  '같다는': 1,
#  '재밌어': 1,
#  '힘듦이': 1,
#  '있으셨': 1,
#  '있었는데요': 1,
#  '좋지만': 1,
#  '그렇기에': 1,
#  '필요할까': 1,
#  '같군요': 1,
#  '문란하게': 1,
#  '복잡하고': 1,
#  '많겠지만': 1,
#  '간단한': 1,
#  '용하는': 1,
#  '많다고': 1,
#  '좋아하시는': 1,
#  '아니던가요': 1,
#  '없으시고': 1,
#  '안타깝네요': 1,
#  '신중하게': 1,
#  '힘든지를': 1,
#  '있을것': 1,
#  '머니로': 1,
#  '드물어요': 1,
#  '똑같나요': 1,
#  '나빠요': 1,
#  '싫으면': 1,
#  '빠를것': 1,
#  '강력하게': 1,
#  '잔인하고': 1,
#  '좋을텐데': 1,
#  '필요하므로': 1,
#  '해롭게': 1,
#  '그런건': 1,
#  '확실한건': 1,
#  '빠르고': 1,
#  '좁은': 1,
#  '안되요': 1,
#  '무력함': 1,
#  '그렇지': 1,
#  '있다고하네요': 1,
#  '무건수': 1,
#  '좀전에': 1,
#  '심하다고': 1,
#  '좋답니다': 1,
#  '아니다': 1,
#  '없는것이': 1,
#  '아니며': 1,
#  '높아': 1,
#  '무리한': 1,
#  '없거든요': 1,
#  '아무렇지': 1,
#  '높다고': 1,
#  '없으나': 1,
#  '계시나요': 1,
#  '쉬운': 1,
#  '필요없고': 1,
#  '있었지만': 1,
#  '힘든데': 1,
#  '아니니깐': 1,
#  '까칠하십니다': 1,
#  '그러는데요': 1,
#  '좋았던': 1,
#  '안된다': 1,
#  '성공한다': 1,
#  '성공하는': 1,
#  '있으신': 1,
#  '안되는걸': 1,
#  '소중한': 1,
#  '저렴하게': 1,
#  '충분하기': 1,
#  '불가피한': 1,
#  '좋구요': 1,
#  '필요하다면': 1,
#  '화해서': 1,
#  '변하지': 1,
#  '심한': 1,
#  '특별한': 1,
#  '있게': 1,
#  '더러운': 1,
#  '중대하진': 1,
#  '불과하니': 1,
#  '당했는데': 1,
#  '야한게': 1,
#  '아님니다': 1,
#  '당연히아니겠죠': 1,
#  '비슷하게': 1,
#  '없지': 1,
#  '많아': 1,
#  '망한것': 1,
#  '같은것은': 1,
#  '필요해서': 1,
#  '힘들다': 1,
#  '부어져야': 1,
#  '없냐': 1,
#  '그러니깐': 1,
#  '풍부하게': 1,
#  '안되는것이지만': 1,
#  '있거든요': 1,
#  '안타깝더군요': 1,
#  '망합니다': 1,
#  '철저한': 1,
#  '가득한': 1,
#  '당하더라도': 1,
#  '있을지': 1,
#  '억울해': 1,
#  '유명하다': 1,
#  '있습니까': 1,
#  '아닙니까': 1,
#  '있나': 1,
#  '폭넓기': 1,
#  '딱이라고': 1,
#  '안된다구요': 1,
#  '같은것이': 1,
#  '그런게': 1,
#  '아닐까': 1,
#  '부탁드려용': 1,
#  '그래': 1,
#  '심할까': 1,
#  '부족하지만': 1,
#  '우울한': 1,
#  '그랬을까요': 1,
#  '아니오니': 1,
#  '나쁘지': 1,
#  '좋겠어요': 1,
#  '같지': 1,
#  '이상하지': 1,
#  '궁금하신': 1,
#  '좋아하는': 1,
#  '좋아한다': 1,
#  '유명한': 1,
#  '심해서': 1,
#  '강합니다': 1,
#  '같기도': 1,
#  '행복한': 1,
#  '가능하지만': 1,
#  '그럴수가': 1,
#  '괜찮나요': 1,
#  '불쌍한': 1,
#  '안되니': 1,
#  '아니랍니다': 1,
#  '잔인한': 1,
#  '아니니': 1,
#  '어떻한': 1,
#  '궁금하고': 1,
#  '궁금해요': 1,
#  '유일한': 1,
#  '무모하게': 1,
#  '딱한': 1,
#  '미친다면': 1,
#  '안되겠구나': 1,
#  '아니군요': 1,
#  '있었어': 1,
#  '필요하다': 1,
#  '망하여': 1,
#  '아까': 1,
#  '명확한': 1,
#  '위대한': 1,
#  '심하게': 1,
#  '성숙하다는지': 1,
#  '힘드시죠': 1,
#  '새로': 1,
#  '부족한': 1,
#  '동일한': 1,
#  '입니당': 1,
#  '그런데요': 1,
#  '성장하신다면': 1,
#  '심함': 1,
#  '어엿한': 1,
#  '높은가요': 1,
#  '높아요': 1,
#  '넓답니다': 1,
#  '불가능하더라': 1,
#  '그만하세요': 1,
#  '실하군요': 1,
#  '없나': 1,
#  '스럽죠': 1,
#  '머니에': 1,
#  '없도록': 1,
#  '빨간줄': 1,
#  '이런것': 1,
#  '더있나요': 1,
#  '사소한것이라도': 1,
#  '부탁드릴게요': 1,
#  '사소한': 1,
#  '비참합니까': 1,
#  '그러지': 1,
#  '짧아서': 1,
#  '죄송하고요': 1,
#  '있는게': 1,
#  '낮아서': 1,
#  '있겠습니다': 1,
#  '충분하다': 1,
#  '희미해질': 1,
#  '가까운': 1,
#  '안됨': 1,
#  '아퍼': 1,
#  '편한': 1,
#  '비슷한것까지': 1,
#  '선량한': 1,
#  '그랬는진': 1,
#  '싫어하셨구요': 1,
#  '재밌게': 1,
#  '입니다만': 1,
#  '당하게': 1,
#  '재밌으니': 1,
#  '심합니다': 1,
#  '확실한거면': 1,
#  '안되지': 1,
#  '야하시고': 1,
#  '미치': 1,
#  '당했고': 1,
#  '미안한': 1,
#  '재밌습니다': 1,
#  '가능합니다만': 1,
#  '바람직한': 1,
#  '작죠': 1,
#  '싫어하시는': 1,
#  '힘들었습니다': 1,
#  '아픈': 1,
#  '같았습니다': 1,
#  '아닐테지만': 1,
#  '불가능할까': 1,
#  '없는지': 1,
#  '엄연히': 1,
#  '안됬을시': 1,
#  '재미있는': 1,
#  '유사한': 1,
#  '있는거져': 1,
#  '어떨지': 1,
#  '아님': 1,
#  '싫어서': 1,
#  '안되는데요': 1,
#  '안좋으니까': 1,
#  '바람직하지': 1,
#  '같구': 1,
#  '죄송합니다': 1,
#  '같은데에': 1,
#  '망하게': 1,
#  '굉장해서': 1,
#  '해롭습니다': 1,
#  '가능하세요': 1,
#  '그렇죠': 1,
#  '재밌죠': 1,
#  '아닐지': 1,
#  '안된다는': 1,
#  '음란해서가': 1,
#  '난감하죠': 1,
#  '떳떳한': 1,
#  '같은게': 1,
#  '적합한': 1,
#  '있겠죠': 1,
#  '적당한': 1,
#  '있겠군요': 1,
#  '번듯한': 1,
#  '없었습니다': 1,
#  '성장하는': 1,
#  '영원히': 1,
#  '아니거든': 1,
#  '그렇기': 1,
#  '있을것이다': 1,
#  '심하다면': 1,
#  '그럼에도': 1,
#  '있는것': 1,
#  '부적절하게': 1,
#  '미쳐가고': 1,
#  '재밌으면서': 1,
#  '급하게': 1,
#  '높겠지요': 1,
#  '다를게': 1,
#  '무서워요': 1,
#  '같자나요': 1,
#  '아쉽긴': 1,
#  '아쉽네요': 1,
#  '좋아하고': 1,
#  '안된다는거': 1,
#  '불가능하구요': 1,
#  '어려워도': 1,
#  '솔직히말하고': 1,
#  '나쁘진': 1,
#  '좋다고': 1,
#  '알맞은': 1,
#  '같진': 1,
#  '많은것도': 1,
#  '좋아요': 1,
#  '더러워요': 1,
#  '재밌어요': 1,
#  '야하는': 1,
#  '평등하게': 1,
#  '열광합니다': 1,
#  '원만하게': 1,
#  '뻔합니다': 1,
#  '반가워요': 1,
#  '중요한게': 1,
#  '아름답지': 1,
#  '없었는데요': 1,
#  '많이나옵니다': 1,
#  '당해도': 1,
#  '단단하시다면': 1,
#  '담하기': 1,
#  '어렵지만': 1,
#  '밀접한': 1,
#  '싫어하는': 1,
#  '꾸준히': 1,
#  '나쁘지만': 1,
#  '고마워요': 1,
#  '가능하니': 1,
#  '필요하실': 1,
#  '그러는': 1,
#  '강해요': 1,
#  '좋다': 1,
#  '어렵겠지요': 1,
#  '있기에': 1,
#  '어렵고': 1,
#  '같으며': 1,
#  '없구여': 1,
#  '당연합니다': 1,
#  '불안해서': 1,
#  '없을까요': 1,
#  '당해': 1,
#  '소홀해질': 1,
#  '없다는데': 1,
#  '안되는지': 1,
#  '조급하지': 1,
#  '그러잖아도': 1,
#  '확실하게': 1,
#  '위험하고': 1,
#  '높죠': 1,
#  '필요해': 1,
#  '엄청난': 1,
#  '크고는': 1,
#  '궁금하여': 1,
#  '황당해서요': 1,
#  '있었고': 1,
#  '나태함을': 1,
#  '성실하고': 1,
#  '근면한': 1,
#  '조용히': 1,
#  '힘들거에요': 1,
#  '억울합니다': 1,
#  '화하는': 1,
#  '성장하고': 1,
#  '가능해서': 1,
#  '없었고': 1,
#  '다름이': 1,
#  '어렵게': 1,
#  '그렇더라도': 1,
#  '뛰어나야되': 1,
#  '좋아하기': 1,
#  '있어야하고': 1,
#  '필요한가요': 1,
#  '부끄러운': 1,
#  '미친다': 1,
#  '경미한': 1,
#  '많을': 1,
#  '힘들었기에': 1,
#  '그럴거라고는': 1,
#  '있는냐': 1,
#  '상당한': 1,
#  '흔하고': 1,
#  '그래도': 1,
#  '건강하셨으면': 1,
#  '부족하여': 1,
#  '심했겠어요': 1,
#  '궁금하셨군요': 1,
#  '실패한': 1,
#  '짧은': 1}

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')

# %% [markdown]
# ## '청소년 도박 예방','청소년 도박 치료' 키워드 분석

# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request as rq
import pandas as pd

global news_df

def News():
    global keyword, num, news_df, url,page_num
    
    keyword = input('검색 키워드를 입력해주세요')
    keyword = urllib.parse.quote(keyword) #퍼센트인코딩 #URL에 문자를 표현하는 인코딩방법(URL에 한글이 섞이면 오류 발생)
    num = int(input('필요한 뉴스기사의 숫자를 입력해주세요'))
    
    news_df = pd.DataFrame(columns=['title','url']) 
    
    page_num=1
    i=0 #크롤링한 기사의 수
    while num > i:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query='+keyword+'&start='+str(page_num)
        html = rq.urlopen(url)
        bs = BeautifulSoup(html,'html.parser')
        texts = bs.find_all(class_='news_tit')

        for text in texts:
            news_df.loc[i,'title'] = text.get_text()
            news_df.loc[i,'url'] = text['href']
            i +=1
            if i == num:
                break
        page_num +=10
    return news_df

News()
# Out:
# 검색 키워드를 입력해주세요 청소년 도박 예방
# 필요한 뉴스기사의 숫자를 입력해주세요 1000
#                                      title  \
# 0       문경대 학생상담센터·구미중독관리통합지원센터, 중독예방 업무협약
# 1    "공원은 밤 8시부터 순찰" 청소년이 원하는 치안정책은…고교생 참여
# 2        세종충북도박예방치유센터, 옥천 청소년 도박문제 해결 '맞손'
# 3           남편 도박 빚에 극단적 선택…일가족 3명 숨진 채 발견
# 4                청소년불법도박, 어떠한 경우에도 선처 불가능해
# ..                                     ...
# 995       도박문제관리센터 부산센터, '청소년 도박 예방' 연수 실시
# 996        당진시보건소, 한국도박문제관리 대전센터와 업무 협약 가져
# 997           당진시보건소, 한국도박문제관리센터와 업무 협약 가져
# 998              부안군, 청소년 안전망 위기대응 예방교육 마련
# 999                       청소년 도박문제 예방 '맞손'
#
#                                                    url
# 0    http://www.kyongbuk.co.kr/news/articleView.htm...
# 1                https://www.news1.kr/articles/4756348
# 2    http://www.newsis.com/view/?id=NISX20220720_00...
# 3    http://www.segye.com/content/html/2022/07/25/2...
# 4    http://www.globalepic.co.kr/view.php?ud=202207...
# ..                                                 ...
# 995  http://www.sisaon.co.kr/news/articleView.html?...
# 996  http://www.viva100.com/main/view.php?key=20200...
# 997  http://www.ggilbo.com/news/articleView.html?id...
# 998  https://www.ibuan.com/news/articleView.html?id...
# 999  http://www.ccdailynews.com/news/articleView.ht...
#
# [1000 rows x 2 columns]

# %%
import re
target = news_df['title'].values #Series.values = array
title_list = target.tolist() # array > list
text = ' '.join(title_list) #list들을 공백으로 구분해서 연결
text = re.sub('[^가-힣]+',' ',text) #한글 이외는 공백으로 대체

# %%
#konlpy(콘엘피) = 형태소 분석
from konlpy.tag import Okt
from collections import Counter
okt = Okt() #객체형성

morph = okt.pos(text) #형태소로 변환 #word= 단어 / tag=품사
morph

noun_list =[]
stop_words = ['도박', '청소년', '치료', '중독','문제','한국','도박중독','실시','업무','불법','게임','예방','서울','경남','대상','복지','제주','학생','위험','충북','단박','전북','경기']
for word, tag in morph: #word= 단어 / tag=품사
    if(tag=='Noun') & (len(word)>1): #noun이고 단어가 1글자 이상인것(1글자는 보통 조사이기때문)
        if word not in stop_words:
            noun_list.append(word)

count = Counter(noun_list) #단어별 숫자세주기
data =dict(count.most_common(20)) #빈도수 정리 내림차(30위까지만)
series = pd.Series(data)
df=pd.DataFrame(series, columns=['cnt'])
df
# Out:
#      cnt
# 센터   459
# 관리   271
# 교육   217
# 협약    88
# 교육청   83
# 캠페인   65
# 상담    64
# 학교    61
# 온라인   53
# 활동    53
# 의원    43
# 개최    41
# 체결    32
# 조례    32
# 대회    30
# 사이버   28
# 심각    28
# 발의    28
# 지원    27
# 연수    25

# %%
import pandas as pd
# df.to_excel('청소년_도박_예방.xlsx')
df.to_excel('청소년_도박_치료.xlsx')

# %% [markdown]
# - wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

wordcloud = WordCloud(font_path='../visualization/dataset/malgun.ttf', background_color='white',
                     colormap='flare',width=1500,height=1000).generate_from_frequencies(data)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 1499.5, 999.5, -0.5)
